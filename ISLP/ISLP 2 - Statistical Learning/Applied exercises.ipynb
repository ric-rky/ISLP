# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Exercício 8

# %%
college = pd.read_csv('College.csv')

# %%
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college_2 = pd.read_csv('College.csv', index_col = 0)

# %%
college_2
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college_3 = college.rename({'Unnamed: 0': 'College'},
axis=1)

# %%
college_3
# Out:
#                             College Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college_3 = college_3.set_index('College')

# %%
college_3
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college_3.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
college = college_3

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
pd.plotting.scatter_matrix(college[['Top10perc', 'Apps', 'Enroll']])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %%
college.boxplot('Outstate', 'Private')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %%
college['Elite'] = pd.cut(college['Top10perc'],
[0,0.5,1],
labels=['No', 'Yes'])

# %%
college.boxplot('Outstate', 'Elite')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %%
college.plot.hist('Elite', bins = 3)
# Out:
# C:\Users\ricar\AppData\Local\Temp\ipykernel_3400\1430683065.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   college.plot.hist('Elite', bins = 3)
# C:\Users\ricar\AppData\Local\Temp\ipykernel_3400\1430683065.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   college.plot.hist('Elite', bins = 3)
# C:\Users\ricar\AppData\Local\Temp\ipykernel_3400\1430683065.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ...

# %% [markdown]
# ## Exercício 9

# %%
df = pd.read_csv('Auto.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
df.isna()
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration   year  \
# 0    False      False         False       False   False         False  False
# 1    False      False         False       False   False         False  False
# 2    False      False         False       False   False         False  False
# 3    False      False         False       False   False         False  False
# 4    False      False         False       False   False         False  False
# ..     ...        ...           ...         ...     ...           ...    ...
# 392  False      False         False       False   False         False  False
# 393  False      False         False       False   False         False  False
# 394  False      False         False       False   False         False  False
# 395  False      False         False       False   False         False  False
# 396  False      False         False       False   False         False  False
#
#      origin   name
# 0     False  False
# ...

# %%
predictors = ['quantitative', 'qualitative']

for _ in predictors:
    if _ == predictors[0]:
        print("The quantitative predictors are: mpg, cylinders, displacement, weight, acceleration, and year.")
        print("Horsepower might also be quantitative after data cleaning.")
    else:
        print("The qualitative predictors are: origin and name.")
# Out:
# The quantitative predictors are: mpg, cylinders, displacement, weight, acceleration, and year.
# Horsepower might also be quantitative after data cleaning.
# The qualitative predictors are: origin and name.

# %%
quant = ['mpg', 'cylinders', 'displacement', 'weight', 'acceleration', 'year']
quali = ['origin', 'name', 'horse power']

# %%
df['horsepower'].dtype
# Out:
# dtype('O')

# %%
non_num = []

for value in df['horsepower']:
    if not isinstance(value, (int, float)):
        print(f"Non-numeric value found: {value}.")
        non_num.append(value)
# Out:
# Non-numeric value found: 130.
# Non-numeric value found: 165.
# Non-numeric value found: 150.
# Non-numeric value found: 150.
# Non-numeric value found: 140.
# Non-numeric value found: 198.
# Non-numeric value found: 220.
# Non-numeric value found: 215.
# Non-numeric value found: 225.
# Non-numeric value found: 190.
# Non-numeric value found: 170.
# Non-numeric value found: 160.
# Non-numeric value found: 150.
# Non-numeric value found: 225.
# Non-numeric value found: 95.
# Non-numeric value found: 95.
# Non-numeric value found: 97.
# Non-numeric value found: 85.
# Non-numeric value found: 88.
# Non-numeric value found: 46.
# Non-numeric value found: 87.
# Non-numeric value found: 90.
# Non-numeric value found: 95.
# Non-numeric value found: 113.
# Non-numeric value found: 90.
# Non-numeric value found: 215.
# Non-numeric value found: 200.
# Non-numeric value found: 210.
# Non-numeric value found: 193.
# Non-numeric value found: 88.
# Non-numeric value found: 90.
# ...

# %%
len(non_num)
# Out:
# 397

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
df['mpg'].to_numpy().max()
# Out:
# 46.6

# %%
for column in df.columns:
    if column in quant:
        print(f"The maximum and minimum value of the {column} predictor are, respectively: {df[column].to_numpy().max()} and {df[column].to_numpy().min()}.")
# Out:
# The maximum and minimum value of the mpg predictor are, respectively: 46.6 and 9.0.
# The maximum and minimum value of the cylinders predictor are, respectively: 8 and 3.
# The maximum and minimum value of the displacement predictor are, respectively: 455.0 and 68.0.
# The maximum and minimum value of the weight predictor are, respectively: 5140 and 1613.
# The maximum and minimum value of the acceleration predictor are, respectively: 24.8 and 8.0.
# The maximum and minimum value of the year predictor are, respectively: 82 and 70.

# %%
for column in df.columns:
    if column in quant:
        print(f"The mean and the standard deviation of each predictor, with 2 precision decimals, are: {df[column].mean():.2f} and {df[column].std():.2f}.")
# Out:
# The mean and the standard deviation of each predictor, with 2 precision decimals, are: 23.52 and 7.83.
# The mean and the standard deviation of each predictor, with 2 precision decimals, are: 5.46 and 1.70.
# The mean and the standard deviation of each predictor, with 2 precision decimals, are: 193.53 and 104.38.
# The mean and the standard deviation of each predictor, with 2 precision decimals, are: 2970.26 and 847.90.
# The mean and the standard deviation of each predictor, with 2 precision decimals, are: 15.56 and 2.75.
# The mean and the standard deviation of each predictor, with 2 precision decimals, are: 75.99 and 3.69.

# %%
from statistics import quantiles

values = [1.9, 2.0, 2.1, 2.5, 3.0, 3.1, 3.3, 3.7, 6.1, 7.7]

quantiles(values)
# Out:
# [2.075, 3.05, 4.300000000000001]

# %%
df_drop = df.drop(range(11, 86))

# %%
df_drop
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
df_drop.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  322.000000  322.000000    322.000000   322.000000    322.000000
# mean    24.415528    5.378882    187.782609  2935.139752     15.691304
# std      7.905155    1.657398    100.304316   809.138141      2.720887
# min     11.000000    3.000000     68.000000  1649.000000      8.500000
# 25%     18.000000    4.000000    100.250000  2216.000000     14.000000
# 50%     23.900000    4.000000    145.500000  2797.500000     15.500000
# 75%     30.650000    6.000000    250.000000  3516.000000     17.275000
# max     46.600000    8.000000    455.000000  4997.000000     24.800000
#
#              year      origin
# count  322.000000  322.000000
# mean    77.121118    1.596273
# std      3.148592    0.815572
# min     70.000000    1.000000
# 25%     75.000000    1.000000
# 50%     77.000000    1.000000
# 75%     80.000000    2.000000
# max     82.000000    3.000000

# %%
scatter_plot = pd.plotting.scatter_matrix(df, figsize = (12, 12))

# %% [markdown]
# From the previous scatter plot we can draw the following preliminary conclusions:
#
# - While acceleration envokes a normal distribution, both weight and mpg show flat tails like normal distribution and skewness;
# - The couples (displacement, weight), (horsepower, weight) and (horsepower, displacement) show strong linear relationships;
# - The couples (mpg, weight), (horsepower, mpg) and (mpg, displacement) show non-linear relationships.

# %% [markdown]
# Based on the conclusions of the previous question, we elect the features 'weight', 'horsepower' and 'displacement' as to be predictors of 'mpg'.
# Further investigations must be done to find the best model and evaluate whether the interlying relationships are significant.

# %%
from ISLP import load_data

# %%
Boston = load_data('Boston')

# %%
Boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %%
Boston.shape
# Out:
# (506, 13)

# %% [markdown]
# We have that $(\text{rows}, \text{columns}) = (506, 13)$.
# Each row is a town in Boston area. Columns are factors which can influence house prices.

# %%
plots = pd.plotting.scatter_matrix(Boston, figsize = (12, 12))

# %% [markdown]
# We can infer that rm and medv probably follow normal distributions.
# The pair (rm, medv) shows a strong linear relationship.

# %%
Boston.corrwith(Boston['crim'])
# Out:
# crim       1.000000
# zn        -0.200469
# indus      0.406583
# chas      -0.055892
# nox        0.420972
# rm        -0.219247
# age        0.352734
# dis       -0.379670
# rad        0.625505
# tax        0.582764
# ptratio    0.289946
# lstat      0.455621
# medv      -0.388305
# dtype: float64

# %%
Boston.corrwith(Boston['crim']).min()
# Out:
# -0.3883046085868113

# %% [markdown]
# We set that crim and medv has the strongest negative correlation, and crim and rad and tax has the strongest positive correlation.

# %%
import matplotlib.pyplot as plt

# %%
Boston.boxplot(column = 'crim', by = 'rad')
# Out:
# <Axes: title={'center': 'crim'}, xlabel='rad'>

# %%
plt.scatter(Boston['tax'], Boston['crim'])
plt.xlabel('Taxes (tax)')
plt.ylabel('Crimes (crim)')
plt.show()

# %%
Boston['tax'].iloc[Boston['crim'].argmax()]
# Out:
# 666

# %%
# Top ten suburbs with high crime rate
Boston.iloc[Boston['crim'].nlargest(10).index]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 380  88.9762  0.0   18.1     0  0.671  6.968   91.9  1.4165   24  666
# 418  73.5341  0.0   18.1     0  0.679  5.957  100.0  1.8026   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
# 410  51.1358  0.0   18.1     0  0.597  5.757  100.0  1.4130   24  666
# 414  45.7461  0.0   18.1     0  0.693  4.519  100.0  1.6582   24  666
# 404  41.5292  0.0   18.1     0  0.693  5.531   85.4  1.6074   24  666
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 427  37.6619  0.0   18.1     0  0.679  6.202   78.7  1.8629   24  666
# 413  28.6558  0.0   18.1     0  0.597  5.155  100.0  1.5894   24  666
# 417  25.9406  0.0   18.1     0  0.679  5.304   89.1  1.6475   24  666
#
#      ptratio  lstat  medv
# 380     20.2  17.21  10.4
# 418     20.2  20.62   8.8
# 405     20.2  22.98   5.0
# 410     20.2  10.11  15.0
# 414     20.2  36.98   7.0
# 404     20.2  27.38   8.5
# ...

# %%
# Top ten suburbs with high tax rate
Boston.iloc[Boston['tax'].nlargest(10).index]
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 488  0.15086  0.0  27.74     0  0.609  5.454  92.7  1.8209    4  711     20.1
# 489  0.18337  0.0  27.74     0  0.609  5.414  98.3  1.7554    4  711     20.1
# 490  0.20746  0.0  27.74     0  0.609  5.093  98.0  1.8226    4  711     20.1
# 491  0.10574  0.0  27.74     0  0.609  5.983  98.8  1.8681    4  711     20.1
# 492  0.11132  0.0  27.74     0  0.609  5.983  83.5  2.1099    4  711     20.1
# 356  8.98296  0.0  18.10     1  0.770  6.212  97.4  2.1222   24  666     20.2
# 357  3.84970  0.0  18.10     1  0.770  6.395  91.0  2.5052   24  666     20.2
# 358  5.20177  0.0  18.10     1  0.770  6.127  83.4  2.7227   24  666     20.2
# 359  4.26131  0.0  18.10     0  0.770  6.112  81.3  2.5091   24  666     20.2
# 360  4.54192  0.0  18.10     0  0.770  6.398  88.0  2.5182   24  666     20.2
#
#      lstat  medv
# 488  18.06  15.2
# 489  23.97   7.0
# 490  29.68   8.1
# 491  18.07  13.6
# 492  13.35  20.1
# ...

# %%
Boston.iloc[Boston['ptratio'].nlargest(10).index]
# Out:
#         crim    zn  indus  chas    nox     rm   age      dis  rad  tax  \
# 354  0.04301  80.0   1.91     0  0.413  5.663  21.9  10.5857    4  334
# 355  0.10659  80.0   1.91     0  0.413  5.936  19.5  10.5857    4  334
# 127  0.25915   0.0  21.89     0  0.624  5.693  96.0   1.7883    4  437
# 128  0.32543   0.0  21.89     0  0.624  6.431  98.8   1.8125    4  437
# 129  0.88125   0.0  21.89     0  0.624  5.637  94.7   1.9799    4  437
# 130  0.34006   0.0  21.89     0  0.624  6.458  98.9   2.1185    4  437
# 131  1.19294   0.0  21.89     0  0.624  6.326  97.7   2.2710    4  437
# 132  0.59005   0.0  21.89     0  0.624  6.372  97.9   2.3274    4  437
# 133  0.32982   0.0  21.89     0  0.624  5.822  95.4   2.4699    4  437
# 134  0.97617   0.0  21.89     0  0.624  5.757  98.4   2.3460    4  437
#
#      ptratio  lstat  medv
# 354     22.0   8.05  18.2
# 355     22.0   5.57  20.6
# 127     21.2  17.19  16.2
# 128     21.2  15.39  18.0
# 129     21.2  18.34  14.3
# ...

# %%
Boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %%
Boston.chas.max()
# Out:
# 1

# %%
# The value of chas is 1 if the suburb tracts bounds river; otherwise, 0
Boston['chas'].value_counts()[1]
# Out:
# 35

# %%
Boston['ptratio'].median()
# Out:
# 19.05

# %%
Boston['medv'].argmin()
# Out:
# 398

# %%
Boston.loc[398]
# Out:
# crim        38.3518
# zn           0.0000
# indus       18.1000
# chas         0.0000
# nox          0.6930
# rm           5.4530
# age        100.0000
# dis          1.4896
# rad         24.0000
# tax        666.0000
# ptratio     20.2000
# lstat       30.5900
# medv         5.0000
# Name: 398, dtype: float64

# %%
Boston.loc[398].describe()
# Out:
# count     13.000000
# mean      69.990569
# std      181.118942
# min        0.000000
# 25%        1.489600
# 50%       18.100000
# 75%       30.590000
# max      666.000000
# Name: 398, dtype: float64

# %%
Boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
Boston[Boston['rm'] > 7].__len__()
# Out:
# 64

# %%
Boston[Boston['rm'] > 8].__len__()
# Out:
# 13

# %%
Boston[Boston['rm'] > 8].describe()
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio      lstat  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000  13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538   4.310000
# std    24.608723   1.883955   5.332532  110.971063   2.410580   1.373566
# ...
